# %% [markdown]
# Import modules

# %%
import os
import pickle
import numpy as np
import pandas as pd
import geometricus as gm
from sklearn.decomposition import PCA
from variables import CAZY_DATA, STRUCTURE_CLUSTERING
from numba.core.errors import NumbaDeprecationWarning, NumbaPendingDeprecationWarning
import warnings
import umap as UMAP
import plotly.graph_objects as go

warnings.simplefilter('ignore', category=NumbaDeprecationWarning)
warnings.simplefilter('ignore', category=NumbaPendingDeprecationWarning)
# Out:
# /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %% [markdown]
# Handling arguments

# %%
# Arguments
structures_folder = '../../Data/AF_core'
resolution = 10 
n_threads = 60 
kmer = 8 
radius = 5

# Handle kmer/radius fragmentation logic
if kmer and radius:
    split = [
        gm.SplitInfo(gm.SplitType.KMER, kmer), 
        gm.SplitInfo(gm.SplitType.RADIUS, radius)
        ]
elif kmer and not radius:
    split = [gm.SplitInfo(gm.SplitType.KMER, kmer)]
elif not kmer and radius:
    split = [gm.SplitInfo(gm.SplitType.RADIUS, radius)]
else:
    raise ValueError('Fragmentation types cannot be both null')

# %% [markdown]
# Run Geometricus experiment

# %%
# Run Geometricus
invariants, _ = gm.get_invariants_for_structures(
    structures_folder, 
    n_threads = n_threads,
    split_infos = split,
    moment_types = ["O_3", "O_4", "O_5", "F"]
    )

shapemer_class = gm.Geometricus.from_invariants(
    invariants, 
    protein_keys = [structure for structure in os.listdir(structures_folder)], 
    resolution = resolution
    )

shapemer_count_matrix = shapemer_class.get_count_matrix()

# Normalizationfor protein length
shapemer_sum = np.sum(shapemer_count_matrix, axis = 1)
normalized_matrix = shapemer_count_matrix/shapemer_sum[:, None]
# Out:
# Found 3184 protein structures
#   0%|          | 0/3184 [00:00<?, ?it/s]@> 954 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1164 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1088 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1068 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1075 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1078 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1382 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1004 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1121 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1405 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1466 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1266 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1404 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1543 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1178 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1093 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1220 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1081 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1357 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1504 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1284 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1407 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1083 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1294 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1454 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 965 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1634 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1366 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1317 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1520 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1339 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1616 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1064 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1457 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1320 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1404 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1083 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1063 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1540 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1339 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1478 atoms and 1 coordinate set(s) were parsed in 0.33s.
# @> 1204 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1324 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1452 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1453 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1588 atoms and 1 coordinate set(s) were parsed in 0.31s.
# @> 1541 atoms and 1 coordinate set(s) were parsed in 0.32s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.33s.
# @> 1377 atoms and 1 coordinate set(s) were parsed in 0.33s.
# @> 1331 atoms and 1 coordinate set(s) were parsed in 0.34s.
# @> 1468 atoms and 1 coordinate set(s) were parsed in 0.34s.
# @> 1425 atoms and 1 coordinate set(s) were parsed in 0.35s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.36s.
# @> 1547 atoms and 1 coordinate set(s) were parsed in 0.37s.
# @> 1845 atoms and 1 coordinate set(s) were parsed in 0.36s.
# @> 1456 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1633 atoms and 1 coordinate set(s) were parsed in 0.36s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1613 atoms and 1 coordinate set(s) were parsed in 0.38s.
# @> 1083 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1376 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1121 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1335 atoms and 1 coordinate set(s) were parsed in 0.33s.
# @> 1274 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1282 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1186 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1680 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 965 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1625 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1558 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1312 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1329 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1068 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1500 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1108 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1075 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1485 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1379 atoms and 1 coordinate set(s) were parsed in 0.37s.
# @> 1427 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1380 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1392 atoms and 1 coordinate set(s) were parsed in 0.31s.
# @> 1525 atoms and 1 coordinate set(s) were parsed in 0.27s.
#   0%|          | 1/3184 [00:14<12:56:18, 14.63s/it]@> 1321 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1069 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1050 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1463 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1350 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1057 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1850 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.32s.
# @> 1387 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1317 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1082 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1156 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1800 atoms and 1 coordinate set(s) were parsed in 0.36s.
# @> 1389 atoms and 1 coordinate set(s) were parsed in 0.55s.
# @> 1455 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1386 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1390 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1720 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1395 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1090 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 838 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1629 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 980 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1078 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1440 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1689 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1409 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1168 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1533 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1367 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1317 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1099 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1357 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1405 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1307 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1484 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1388 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1289 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1432 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1458 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1513 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1343 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1346 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1525 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1316 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 2022 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1158 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1335 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1493 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1357 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1158 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1312 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1499 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1367 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1342 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1590 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1362 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1703 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1598 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1302 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1067 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1154 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1506 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1352 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 972 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1747 atoms and 1 coordinate set(s) were parsed in 0.32s.
# @> 1424 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1119 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1422 atoms and 1 coordinate set(s) were parsed in 0.35s.
# @> 1341 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1380 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1545 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1634 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 822 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1023 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1511 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1059 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1541 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1618 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1545 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1320 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1318 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1069 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1482 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1336 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1145 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1402 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1480 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1400 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1430 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1461 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1591 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 829 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1842 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1554 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1477 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1729 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1050 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1416 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1085 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1059 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1219 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 942 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1317 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1772 atoms and 1 coordinate set(s) were parsed in 0.37s.
# @> 1763 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1594 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1615 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1291 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1402 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1645 atoms and 1 coordinate set(s) were parsed in 0.34s.
# @> 1327 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1654 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1375 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1062 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1383 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1425 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1336 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1097 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1283 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1274 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 835 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1390 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1069 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 823 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1503 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1312 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1090 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1126 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1507 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1243 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1385 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1329 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1156 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1300 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1675 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 951 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1526 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1171 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1125 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1730 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1392 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1540 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1339 atoms and 1 coordinate set(s) were parsed in 0.19s.
#   0%|          | 2/3184 [00:18<7:09:46,  8.10s/it] @> 1111 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1375 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 836 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1504 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1310 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1288 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1337 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1058 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1308 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1114 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1372 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1463 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1083 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1389 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1405 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1391 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 867 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1316 atoms and 1 coordinate set(s) were parsed in 0.38s.
# @> 1436 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1129 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1369 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1115 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1369 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1669 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1485 atoms and 1 coordinate set(s) were parsed in 0.31s.
# @> 2005 atoms and 1 coordinate set(s) were parsed in 0.34s.
# @> 1458 atoms and 1 coordinate set(s) were parsed in 0.42s.
# @> 1518 atoms and 1 coordinate set(s) were parsed in 0.18s.
#   6%|▋         | 206/3184 [00:18<02:23, 20.76it/s]@> 1398 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 833 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1408 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1727 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1516 atoms and 1 coordinate set(s) were parsed in 0.35s.
# @> 1302 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1463 atoms and 1 coordinate set(s) were parsed in 0.33s.
# @> 1055 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1413 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1577 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1389 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1380 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1084 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1702 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1466 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1847 atoms and 1 coordinate set(s) were parsed in 0.34s.
# @> 1316 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1068 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1788 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1682 atoms and 1 coordinate set(s) were parsed in 0.32s.
# @> 1252 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1272 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 845 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1641 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1147 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1068 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1338 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1293 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1321 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1369 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1316 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1064 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1552 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1538 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1333 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 926 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1496 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1088 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1459 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1385 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1371 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1547 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1531 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1310 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1818 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1509 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1152 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1294 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1386 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1093 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1121 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1368 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1272 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1096 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1410 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1542 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1490 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1741 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1736 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1359 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1083 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1345 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1086 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1610 atoms and 1 coordinate set(s) were parsed in 0.22s.
#   8%|▊         | 256/3184 [00:19<01:54, 25.50it/s]@> 1075 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1649 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1097 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1341 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1061 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1054 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1427 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1006 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1391 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1393 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1352 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1319 atoms and 1 coordinate set(s) were parsed in 0.13s.
#   9%|▉         | 287/3184 [00:19<01:34, 30.53it/s]@> 1012 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1259 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1383 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1392 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1536 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1399 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1405 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1059 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1755 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1399 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1150 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1656 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1478 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1028 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 827 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1075 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1758 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 824 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1087 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1071 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1115 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1047 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1316 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1110 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1304 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1585 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1386 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1539 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1303 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1682 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1501 atoms and 1 coordinate set(s) were parsed in 0.15s.
#  10%|▉         | 315/3184 [00:19<01:21, 35.26it/s]@> 1386 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1051 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1766 atoms and 1 coordinate set(s) were parsed in 0.31s.
# @> 1321 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1080 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1066 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1620 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1433 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1319 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1438 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1064 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1378 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1861 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1473 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1369 atoms and 1 coordinate set(s) were parsed in 0.13s.
#  11%|█         | 336/3184 [00:19<01:10, 40.42it/s]@> 1781 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1076 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1050 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1325 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1059 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1292 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1407 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1666 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1379 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1855 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1074 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1335 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1282 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1051 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1051 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1508 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1672 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1074 atoms and 1 coordinate set(s) were parsed in 0.14s.
#  11%|█         | 355/3184 [00:19<01:03, 44.48it/s]@> 1409 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1337 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 823 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1069 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 823 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1392 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1465 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1316 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1592 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1682 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1070 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1475 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 669 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1698 atoms and 1 coordinate set(s) were parsed in 0.38s.
# @> 1508 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1064 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1394 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1337 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1627 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 834 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1482 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1704 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1118 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1274 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1323 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1462 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1515 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 867 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> 1317 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1074 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> 1115 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1307 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> 1331 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1085 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 822 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1317 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1436 atoms and 1 coordinate set(s) were parsed in 0.12s.
#  12%|█▏        | 371/3184 [00:20<01:16, 36.66it/s]@> 1411 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1345 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1609 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1317 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1432 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1069 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1532 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1464 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1084 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1737 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1753 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1539 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1099 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1081 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1299 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1709 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1276 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1282 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1352 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1320 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1393 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1388 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1482 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1331 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1512 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1715 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1451 atoms and 1 coordinate set(s) were parsed in 0.11s.
#  13%|█▎        | 404/3184 [00:20<00:55, 50.51it/s]@> 823 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1061 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1403 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1316 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 833 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1076 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1336 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1611 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 2104 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1511 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1523 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1422 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1379 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 828 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1537 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1849 atoms and 1 coordinate set(s) were parsed in 0.32s.
# @> 1073 atoms and 1 coordinate set(s) were parsed in 0.13s.
#  14%|█▍        | 440/3184 [00:21<00:41, 66.51it/s]@> 1712 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1087 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1257 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1339 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 988 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1201 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1539 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1209 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1139 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 823 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1609 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1362 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1086 atoms and 1 coordinate set(s) were parsed in 0.14s.
#  14%|█▍        | 455/3184 [00:21<00:37, 71.99it/s]@> 1302 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1527 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 828 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1313 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1430 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1499 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1075 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1380 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1274 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1708 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1080 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1462 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1377 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1728 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1372 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1322 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1084 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1459 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1286 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 2113 atoms and 1 coordinate set(s) were parsed in 0.35s.
# @> 1087 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1454 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1503 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1395 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1325 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1085 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1470 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1532 atoms and 1 coordinate set(s) were parsed in 0.22s.
#  15%|█▍        | 474/3184 [00:21<00:36, 73.77it/s]@> 1090 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1380 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1627 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1293 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1855 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1084 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1471 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1084 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1724 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1214 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1351 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1220 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1461 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 853 atoms and 1 coordinate set(s) were parsed in 0.08s.
#  15%|█▌        | 486/3184 [00:21<00:36, 74.18it/s]@> 1580 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1323 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1761 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1081 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1755 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 993 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1331 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1451 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1375 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1667 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1402 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1314 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1078 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1455 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1085 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1460 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1302 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1266 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1075 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1370 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1316 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 824 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1379 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1539 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1368 atoms and 1 coordinate set(s) were parsed in 0.25s.
#  16%|█▌        | 515/3184 [00:21<00:32, 82.15it/s]@> 1357 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1795 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1394 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1395 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1439 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1316 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1062 atoms and 1 coordinate set(s) were parsed in 0.31s.
# @> 1543 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1473 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1336 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1278 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1330 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1508 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1830 atoms and 1 coordinate set(s) were parsed in 0.37s.
# @> 1398 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1532 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1092 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1288 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1164 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1798 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1456 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 815 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1187 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1764 atoms and 1 coordinate set(s) were parsed in 0.32s.
# @> 1349 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1077 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1923 atoms and 1 coordinate set(s) were parsed in 0.36s.
# @> 1401 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1373 atoms and 1 coordinate set(s) were parsed in 0.23s.
#  17%|█▋        | 537/3184 [00:22<00:32, 82.58it/s]@> 1566 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1384 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1124 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1674 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1440 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1317 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1476 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1547 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1760 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1504 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1466 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1674 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1375 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1370 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1609 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1612 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1079 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1690 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1340 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1126 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1284 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1738 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1345 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1472 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1425 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 987 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1380 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1440 atoms and 1 coordinate set(s) were parsed in 0.23s.
#  18%|█▊        | 570/3184 [00:22<00:28, 91.56it/s]@> 815 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1219 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 815 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1466 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1711 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1291 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1337 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1870 atoms and 1 coordinate set(s) were parsed in 0.38s.
# @> 1401 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1732 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1469 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1345 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 833 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1061 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1545 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1248 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1690 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1548 atoms and 1 coordinate set(s) were parsed in 0.25s.
#  19%|█▊        | 591/3184 [00:22<00:27, 95.79it/s]@> 1694 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1084 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1138 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1353 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1602 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1549 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1635 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1322 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1636 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1451 atoms and 1 coordinate set(s) were parsed in 0.23s.
#  19%|█▉        | 610/3184 [00:22<00:24, 105.10it/s]@> 1092 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1717 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1314 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1454 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 852 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1092 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1076 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1534 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1440 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1338 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1146 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1499 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1516 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 864 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1610 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1657 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 840 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1359 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1308 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1597 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1604 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1313 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1303 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1329 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 2146 atoms and 1 coordinate set(s) were parsed in 0.36s.
# @> 847 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 2015 atoms and 1 coordinate set(s) were parsed in 0.29s.
#  20%|█▉        | 624/3184 [00:23<00:28, 88.34it/s] @> 1350 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1440 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1320 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1804 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1329 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1087 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1089 atoms and 1 coordinate set(s) were parsed in 0.32s.
# @> 1423 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1415 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1342 atoms and 1 coordinate set(s) were parsed in 0.18s.
#  20%|██        | 649/3184 [00:24<00:53, 47.37it/s]@> 984 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1509 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1327 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1367 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1743 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1435 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1326 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.32s.
# @> 1525 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1833 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1332 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1528 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1067 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1510 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 859 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1725 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1314 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1475 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1360 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1421 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1723 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1481 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1393 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1622 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1237 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1387 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1582 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1071 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1324 atoms and 1 coordinate set(s) were parsed in 0.08s.
#  21%|██        | 671/3184 [00:24<00:40, 61.32it/s]@> 1334 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1376 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> 1456 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1064 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1469 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1069 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1475 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1335 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1098 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1402 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1523 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1478 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1394 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1697 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1375 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1821 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1356 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1339 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1040 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1366 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 823 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1363 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1374 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1361 atoms and 1 coordinate set(s) were parsed in 0.16s.
#  22%|██▏       | 705/3184 [00:24<00:31, 79.92it/s]@> 1381 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1392 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1385 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1623 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1463 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1485 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1357 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1357 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1003 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1760 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1691 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1762 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1557 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1734 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1380 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1286 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1364 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1487 atoms and 1 coordinate set(s) were parsed in 0.22s.
#  23%|██▎       | 718/3184 [00:24<00:32, 76.13it/s]@> 1263 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1286 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1686 atoms and 1 coordinate set(s) were parsed in 0.16s.
# ...
# @> 1473 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1311 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1373 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1284 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1611 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1429 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1385 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1229 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1675 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1537 atoms and 1 coordinate set(s) were parsed in 0.15s.
#  90%|████████▉ | 2865/3184 [00:48<00:05, 63.02it/s]@> 1081 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1084 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1386 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1116 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1332 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1532 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1399 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1524 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1755 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1604 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1313 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1798 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1555 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1345 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1364 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1092 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1081 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1071 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1170 atoms and 1 coordinate set(s) were parsed in 0.18s.
#  91%|█████████ | 2901/3184 [00:49<00:03, 86.74it/s]@> 1065 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1214 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1394 atoms and 1 coordinate set(s) were parsed in 0.34s.
# @> 1323 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1412 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1366 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1340 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1454 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1255 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1067 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1282 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1111 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1618 atoms and 1 coordinate set(s) were parsed in 0.32s.
# @> 1542 atoms and 1 coordinate set(s) were parsed in 0.32s.
# @> 1312 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1474 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1290 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1405 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1497 atoms and 1 coordinate set(s) were parsed in 0.38s.
# @> 1082 atoms and 1 coordinate set(s) were parsed in 0.21s.
#  92%|█████████▏| 2928/3184 [00:49<00:02, 104.96it/s]@> 1323 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1602 atoms and 1 coordinate set(s) were parsed in 0.33s.
# @> 1076 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1533 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1678 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1397 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1382 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1145 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1511 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1339 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1483 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 857 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1200 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1616 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1553 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1384 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1655 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1292 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1395 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1409 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1505 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1165 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1542 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1419 atoms and 1 coordinate set(s) were parsed in 0.10s.
#  92%|█████████▏| 2943/3184 [00:49<00:02, 85.59it/s] @> 1362 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1424 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1728 atoms and 1 coordinate set(s) were parsed in 0.30s.
# @> 1513 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1338 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1469 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1363 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1325 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1181 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1321 atoms and 1 coordinate set(s) were parsed in 0.08s.
#  93%|█████████▎| 2955/3184 [00:49<00:02, 89.33it/s]@> 1476 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1317 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1034 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 833 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 837 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1628 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1069 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1078 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1187 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1080 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1524 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1394 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1282 atoms and 1 coordinate set(s) were parsed in 0.22s.
#  93%|█████████▎| 2974/3184 [00:49<00:02, 97.35it/s]@> 773 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1151 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1075 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1323 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1219 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1723 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1358 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1466 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1769 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1340 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1088 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1075 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1449 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1456 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1347 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1322 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1063 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1988 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1630 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1511 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1480 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1069 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1076 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1384 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1291 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1418 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1387 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 780 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1389 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1724 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1389 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1623 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1435 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1075 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1720 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1762 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1663 atoms and 1 coordinate set(s) were parsed in 0.21s.
#  94%|█████████▍| 2996/3184 [00:50<00:02, 83.27it/s]@> 1031 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1087 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1110 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1454 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1495 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1415 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1055 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1378 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1108 atoms and 1 coordinate set(s) were parsed in 0.12s.
#  95%|█████████▍| 3020/3184 [00:50<00:01, 105.02it/s]@> 1084 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1392 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1084 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1093 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 988 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 1091 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1095 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1678 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 853 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1375 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1548 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1277 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1462 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.09s.
#  95%|█████████▌| 3034/3184 [00:50<00:01, 103.78it/s]@> 1079 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1597 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1072 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1068 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1531 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1594 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1015 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1469 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1315 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1226 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.12s.
#  96%|█████████▋| 3066/3184 [00:50<00:00, 134.33it/s]@> 1577 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1039 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 828 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1437 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 832 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1730 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1628 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1324 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1084 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1091 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1673 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1326 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1780 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1722 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1378 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1367 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1365 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1354 atoms and 1 coordinate set(s) were parsed in 0.23s.
# @> 1318 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1715 atoms and 1 coordinate set(s) were parsed in 0.33s.
#  97%|█████████▋| 3086/3184 [00:50<00:00, 145.22it/s]@> 1077 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1326 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1346 atoms and 1 coordinate set(s) were parsed in 0.46s.
# @> 1536 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1073 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1305 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1304 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1307 atoms and 1 coordinate set(s) were parsed in 0.12s.
# @> 1185 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1595 atoms and 1 coordinate set(s) were parsed in 0.31s.
# @> 1743 atoms and 1 coordinate set(s) were parsed in 0.36s.
# @> 1472 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1504 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1362 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1588 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1381 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1021 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1366 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1526 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1264 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1079 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1621 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1548 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 851 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1445 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1602 atoms and 1 coordinate set(s) were parsed in 0.26s.
# @> 1170 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1351 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 837 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1080 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1072 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1622 atoms and 1 coordinate set(s) were parsed in 0.27s.
# @> 1407 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1259 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 832 atoms and 1 coordinate set(s) were parsed in 0.11s.
#  97%|█████████▋| 3103/3184 [00:50<00:00, 90.45it/s] @> 1323 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1144 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 799 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 857 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1058 atoms and 1 coordinate set(s) were parsed in 0.14s.
# @> 1586 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1521 atoms and 1 coordinate set(s) were parsed in 0.25s.
# @> 1629 atoms and 1 coordinate set(s) were parsed in 0.29s.
# @> 1049 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 1729 atoms and 1 coordinate set(s) were parsed in 0.28s.
# @> 1490 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 1379 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1357 atoms and 1 coordinate set(s) were parsed in 0.24s.
# @> 1104 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 1064 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 1275 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 1401 atoms and 1 coordinate set(s) were parsed in 0.17s.
#  98%|█████████▊| 3116/3184 [00:51<00:00, 92.85it/s]@> 1559 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 1537 atoms and 1 coordinate set(s) were parsed in 0.22s.
# @> 1325 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 1729 atoms and 1 coordinate set(s) were parsed in 0.23s.
# 100%|██████████| 3184/3184 [00:51<00:00, 62.15it/s]
# Computed invariants in 56.03 seconds
# 100%|██████████| 3184/3184 [00:02<00:00, 1332.82it/s]

# %% [markdown]
# Store matrix with annotations

# %%
proteins = [protein.replace('.pdb', '') for protein in shapemer_class.protein_keys]
shapemers = shapemer_class.shapemer_keys
matrix = pd.DataFrame(normalized_matrix, index = proteins, columns = shapemers)
matrix.to_pickle(f'{STRUCTURE_CLUSTERING}/default_core.pkl')

# %% [markdown]
# Dimensionality reduction

# %%
# UMAP
umap_space = UMAP.UMAP(
    metric = "cosine", 
    n_components = 2
    ).fit_transform(normalized_matrix)

# PCA
pca = PCA()
pca_space = pca.fit_transform(normalized_matrix)

# PCA scree plot
PC_values = np.arange(pca.n_components_) + 1
PC_cumulative = pca.explained_variance_ratio_.cumsum()

# %% [markdown]
# Add annotations to embeddings and prepare them for plotting

# %%
# Add family
with open(f'{CAZY_DATA}/uniprot_family.pkl', 'rb') as dic:
    dic = pickle.load(dic)

# Add annotations to embeddings

umap = pd.DataFrame(umap_space[:, 0:2], index = proteins)
pca = pd.DataFrame(pca_space[:, 0:2], index = proteins)
families = [dic[protein] for protein in proteins]
umap['Family'] = families
pca['Family'] = families

# Disregard AA0
umap = umap[umap['Family'] != 'AA0']
pca = pca[pca['Family'] != 'AA0']

# One Hot Encode families into colors
dummies = pd.get_dummies(umap['Family'])

# Translate family to color
family_color = {
    'AA9' : '#1f77b4',
    'AA10' : '#ff7f0e',
    'AA11' : '#2ca02c',
    'AA13' : '#d62728',
    'AA14' : '#9467bd',
    'AA15' : '#8c564b',
    'AA16' : '#e377c2',
    'AA17' : '#bcbd22'
}
for column in dummies:
    dummies[column] = dummies[column].replace(1, family_color[column])
    dummies[column] = dummies[column].replace(0, 'grey')

# Add all colors
dummies['all'] = umap['Family'].apply(lambda x: family_color[x])

# %% [markdown]
# Plotly

# %%
# Scatter plots
scatter_umap = go.Scatter(
    x = umap[0],
    y = umap[1],
    name = "Default UMAP",
    mode = 'markers',
    visible = True,
    hovertemplate = umap.index.to_list(),
    marker = dict(color = ['grey']*len(dummies))
)

scatter_pca = go.Scatter(
    x = pca[0],
    y = pca[1],
    name = "Default PCA",
    mode = 'markers',
    visible = False,
    hovertemplate = pca.index.to_list(),
    marker=dict(color = ['grey']*len(dummies))
)
x = np.arange(10)
scree_plot = go.Scatter(
    x = PC_values, 
    y = PC_cumulative, 
    visible = False
    )

fig = go.FigureWidget([scatter_umap, scatter_pca, scree_plot])

button_layer_1_height = 1.11
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                
                dict(
                    label = "None",
                    args = [{"marker": {"color":['grey']*len(dummies)}}],
                    method = "restyle"
                ),  

                dict(
                    label = "All",
                    args = [{"marker": {"color":dummies['all']}}],
                    method = "restyle"
                ),  

                dict(
                    label = "AA9",
                    args = [{"marker": {"color": dummies['AA9']}}],
                    method = "restyle"
                ),    

                dict(
                    label = "AA10",
                    args = [{"marker": {"color": dummies['AA10']}}],
                    method = "restyle"
                ),   
                
                dict(
                    label = "AA11",
                    args = [{"marker": {"color": dummies['AA11']}}],
                    method = "restyle"
                ),   

                dict(
                    label = "AA13",
                    args = [{"marker": {"color": dummies['AA13']}}],
                    method = "restyle"
                ), 
                
                dict(
                    label = "AA14",
                    args = [{"marker": {"color": dummies['AA14']}}],
                    method = "restyle"
                ),   

                dict(
                    label = "AA15",
                    args = [{"marker": {"color": dummies['AA15']}}],
                    method = "restyle"
                ),   

                dict(
                    label = "AA16",
                    args = [{"marker": {"color": dummies['AA16']}}],
                    method = "restyle"
                ),                  
                
                dict(
                    label = "AA17",
                    args = [{"marker": {"color": dummies['AA17']}}],
                    method = "restyle"
                ),   

            ]), 
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.20,
            xanchor="left",
            y=button_layer_1_height,
            yanchor="top"
        ),
        dict(
            buttons=list([
                dict(label="UMAP",
                     method="update",
                     args=[{"visible": [True, False, False]},
                           {"title": "UMAP"}]),
                dict(label="PCA",
                     method="update",
                     args=[{"visible": [False, True, False]},
                           {"title": "PCA"}]),
                dict(label="Scree",
                     method="update",
                     args=[{"visible": [False, False, True]},
                           {"title": "Scree plot"}]               
                ),
            ]),
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0,
            xanchor="left",
            y=button_layer_1_height,
            yanchor="top"
        )
    ]
)

# Update size 
fig.update_layout(
    autosize=False,
    width=600,
    height=600)

# Create our callback function
def selection_fn(trace, points, selector):
    # Give shapemer and protein info to normalized_matrix
    df = pd.DataFrame(
        data = normalized_matrix, 
        columns = shapemer_class.shapemer_keys,
        index = [key.split('.')[0] for key in shapemer_class.protein_keys]
        )
    
    # Calculate most frequent shapemer/protein
    point_indeces = points.point_inds
    if point_indeces:
        print(point_indeces)
        points = df.iloc[point_indeces].to_numpy()
        point_names = set(df.iloc[point_indeces].index)
        index = np.unravel_index(np.argmax(points, axis=None), points.shape)
        most_frequent_shapemer = df.columns[index[1]]
        print(most_frequent_shapemer)

        # Map shapemer to residues
        selectedname_residue = dict()
        name_residue = dict(shapemer_class.map_shapemer_to_residues(most_frequent_shapemer))
        for name in point_names:
            if name + '.pdb' in name_residue:
                selectedname_residue[name] = name_residue[name + '.pdb']
        print(selectedname_residue)

fig.data[0].on_selection(selection_fn)
fig.data[1].on_selection(selection_fn)

fig
# Out:
# FigureWidget({
#     'data': [{'hovertemplate': [A0A1B3XTW0, A0A6S6VTC2, A0A1H0DH62, ...,
#                                 A0A084VRN9, A0A6G7P3W3, K1PFV1],
#               'marker': {'color': [grey, grey, grey, ..., grey, grey, grey]},
#               'mode': 'markers',
#               'name': 'Default UMAP',
#               'type': 'scatter',
#               'uid': 'fd437fe8-727e-4155-a5c6-a0ff3c52e99b',
#               'visible': True,
#               'x': array([ -1.7209421 ,   5.0150385 ,   4.5605326 , ..., -10.248204  ,
#                            -0.94421047, -10.1088915 ], dtype=float32),
#               'y': array([ -3.8707855,   4.663015 , -11.406788 , ...,  18.201656 ,  16.358072 ,
#                            17.909603 ], dtype=float32)},
#              {'hovertemplate': [A0A1B3XTW0, A0A6S6VTC2, A0A1H0DH62, ...,
#                                 A0A084VRN9, A0A6G7P3W3, K1PFV1],
#               'marker': {'color': [grey, grey, grey, ..., grey, grey, grey]},
#               'mode': 'markers',
#               'name': 'Default PCA',
#               'type': 'scatter',
#               'uid': '8ef15dd7-67a2-43eb-8514-d1ec93533c3d',
#               'visible': False,
#               'x': array([ 0.01062241, -0.00178002,  0.0150966 , ...,  0.00084159, -0.02084428,
#                            0.00040279]),
#               'y': array([-0.0069273 , -0.00181379, -0.01165984, ..., -0.0023456 ,  0.00335997,
#                           -0.00258173])},
#              {'type': 'scatter',
#               'uid': 'a3a7f61c-e6e3-42c5-b8b9-e33ea82b2420',
#               'visible': False,
#               'x': array([   1,    2,    3, ..., 3182, 3183, 3184]),
#               'y': array([0.02488009, 0.04565084, 0.06271323, ..., 0.99998932, 1.        ,
#                           1.        ])}],
#     'layout': {'autosize': False,
#                'height': 600,
#                'template': '...',
#                'updatemenus': [{'buttons': [{'args': [{'marker': {'color': [grey,
#                                                                             grey,
#                                                                             grey,
#                                                                             ...,
#                                                                             grey,
#                                                                             grey,
#                                                                             grey]}}],
#                                              'label': 'None',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0    #ff7f0e
#    A0A6S6VTC2    #1f77b4
#    A0A1H0DH62    #ff7f0e
#    G8YZS8        #1f77b4
#    A0A7S8HTC2    #1f77b4
#                   ...
#    A0A7R7XBI8    #e377c2
#    A0A127Q5Y5    #ff7f0e
#    A0A084VRN9    #8c564b
#    A0A6G7P3W3    #ff7f0e
#    K1PFV1        #8c564b
#    Name: all, Length: 3184, dtype: object}}],
#                                              'label': 'All',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0       grey
#    A0A6S6VTC2    #1f77b4
#    A0A1H0DH62       grey
#    G8YZS8        #1f77b4
#    A0A7S8HTC2    #1f77b4
#                   ...
#    A0A7R7XBI8       grey
#    A0A127Q5Y5       grey
#    A0A084VRN9       grey
#    A0A6G7P3W3       grey
#    K1PFV1           grey
#    Name: AA9, Length: 3184, dtype: object}}],
#                                              'label': 'AA9',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0    #ff7f0e
#    A0A6S6VTC2       grey
#    A0A1H0DH62    #ff7f0e
#    G8YZS8           grey
#    A0A7S8HTC2       grey
#                   ...
#    A0A7R7XBI8       grey
#    A0A127Q5Y5    #ff7f0e
#    A0A084VRN9       grey
#    A0A6G7P3W3    #ff7f0e
#    K1PFV1           grey
#    Name: AA10, Length: 3184, dtype: object}}],
#                                              'label': 'AA10',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0    grey
#    A0A6S6VTC2    grey
#    A0A1H0DH62    grey
#    G8YZS8        grey
#    A0A7S8HTC2    grey
#                  ...
#    A0A7R7XBI8    grey
#    A0A127Q5Y5    grey
#    A0A084VRN9    grey
#    A0A6G7P3W3    grey
#    K1PFV1        grey
#    Name: AA11, Length: 3184, dtype: object}}],
#                                              'label': 'AA11',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0    grey
#    A0A6S6VTC2    grey
#    A0A1H0DH62    grey
#    G8YZS8        grey
#    A0A7S8HTC2    grey
#                  ...
#    A0A7R7XBI8    grey
#    A0A127Q5Y5    grey
#    A0A084VRN9    grey
#    A0A6G7P3W3    grey
#    K1PFV1        grey
#    Name: AA13, Length: 3184, dtype: object}}],
#                                              'label': 'AA13',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0    grey
#    A0A6S6VTC2    grey
#    A0A1H0DH62    grey
#    G8YZS8        grey
#    A0A7S8HTC2    grey
#                  ...
#    A0A7R7XBI8    grey
#    A0A127Q5Y5    grey
#    A0A084VRN9    grey
#    A0A6G7P3W3    grey
#    K1PFV1        grey
#    Name: AA14, Length: 3184, dtype: object}}],
#                                              'label': 'AA14',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0       grey
#    A0A6S6VTC2       grey
#    A0A1H0DH62       grey
#    G8YZS8           grey
#    A0A7S8HTC2       grey
#                   ...
#    A0A7R7XBI8       grey
#    A0A127Q5Y5       grey
#    A0A084VRN9    #8c564b
#    A0A6G7P3W3       grey
#    K1PFV1        #8c564b
#    Name: AA15, Length: 3184, dtype: object}}],
#                                              'label': 'AA15',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0       grey
#    A0A6S6VTC2       grey
#    A0A1H0DH62       grey
#    G8YZS8           grey
#    A0A7S8HTC2       grey
#                   ...
#    A0A7R7XBI8    #e377c2
#    A0A127Q5Y5       grey
#    A0A084VRN9       grey
#    A0A6G7P3W3       grey
#    K1PFV1           grey
#    Name: AA16, Length: 3184, dtype: object}}],
#                                              'label': 'AA16',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0    grey
#    A0A6S6VTC2    grey
#    A0A1H0DH62    grey
#    G8YZS8        grey
#    A0A7S8HTC2    grey
#                  ...
#    A0A7R7XBI8    grey
#    A0A127Q5Y5    grey
#    A0A084VRN9    grey
#    A0A6G7P3W3    grey
#    K1PFV1        grey
#    Name: AA17, Length: 3184, dtype: object}}],
#                                              'label': 'AA17',
#                                              'method': 'restyle'}],
#                                 'direction': 'down',
#                                 'pad': {'r': 10, 't': 10},
#                                 'showactive': True,
#                                 'x': 0.2,
#                                 'xanchor': 'left',
#                                 'y': 1.11,
#                                 'yanchor': 'top'},
#                                {'buttons': [{'args': [{'visible': [True, False, False]}, {'title': 'UMAP'}],
#                                              'label': 'UMAP',
#                                              'method': 'update'},
#                                             {'args': [{'visible': [False, True, False]}, {'title': 'PCA'}],
#                                              'label': 'PCA',
#                                              'method': 'update'},
#                                             {'args': [{'visible': [False, False, True]}, {'title': 'Scree plot'}],
#                                              'label': 'Scree',
#                                              'method': 'update'}],
#                                 'direction': 'down',
#                                 'pad': {'r': 10, 't': 10},
#                                 'showactive': True,
#                                 'x': 0,
#                                 'xanchor': 'left',
#                                 'y': 1.11,
#                                 'yanchor': 'top'}],
#                'width': 600}
# })
