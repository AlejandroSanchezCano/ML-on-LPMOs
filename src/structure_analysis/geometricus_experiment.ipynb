# %% [markdown]
# Import modules

# %%
import os
import pickle
import numpy as np
import pandas as pd
import geometricus as gm
from sklearn.decomposition import PCA
from variables import CAZY_DATA, STRUCTURE_CLUSTERING
from numba.core.errors import NumbaDeprecationWarning, NumbaPendingDeprecationWarning
import warnings
import umap as UMAP
import plotly.graph_objects as go

warnings.simplefilter('ignore', category=NumbaDeprecationWarning)
warnings.simplefilter('ignore', category=NumbaPendingDeprecationWarning)
# Out:
# /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %% [markdown]
# Handling arguments

# %%
# Arguments
structures_folder = '../../Data/AF_core'
resolution = 1 
n_threads = 4 
kmer = 8 
radius = 5

# Handle kmer/radius fragmentation logic
if kmer and radius:
    split = [
        gm.SplitInfo(gm.SplitType.KMER, kmer), 
        gm.SplitInfo(gm.SplitType.RADIUS, radius)
        ]
elif kmer and not radius:
    split = [gm.SplitInfo(gm.SplitType.KMER, kmer)]
elif not kmer and radius:
    split = [gm.SplitInfo(gm.SplitType.RADIUS, radius)]
else:
    raise ValueError('Fragmentation types cannot be both null')

# %% [markdown]
# Run Geometricus experiment

# %%
# Run Geometricus
invariants, _ = gm.get_invariants_for_structures(
    structures_folder, 
    n_threads = n_threads,
    split_infos = split,
    moment_types = ["O_3", "O_4", "O_5", "F"]
    )

shapemer_class = gm.Geometricus.from_invariants(
    invariants, 
    protein_keys = [structure for structure in os.listdir(structures_folder)], 
    resolution = resolution
    )

shapemer_count_matrix = shapemer_class.get_count_matrix()

# Normalizationfor protein length
shapemer_sum = np.sum(shapemer_count_matrix, axis = 1)
normalized_matrix = shapemer_count_matrix/shapemer_sum[:, None]
# Out:
# Found 3184 protein structures
#   0%|          | 0/3184 [00:00<?, ?it/s]@> 1555 atoms and 1 coordinate set(s) were parsed in 0.39s.
# @> 1762 atoms and 1 coordinate set(s) were parsed in 0.39s.
# @> 1766 atoms and 1 coordinate set(s) were parsed in 0.39s.
# @> 1610 atoms and 1 coordinate set(s) were parsed in 0.39s.
#   0%|          | 1/3184 [00:08<7:07:19,  8.06s/it]@> 1379 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1730 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1367 atoms and 1 coordinate set(s) were parsed in 0.08s.
# @> 1397 atoms and 1 coordinate set(s) were parsed in 0.09s.
#   0%|          | 5/3184 [00:08<1:05:04,  1.23s/it]@> 1075 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1145 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1401 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1320 atoms and 1 coordinate set(s) were parsed in 0.09s.
#   0%|          | 10/3184 [00:08<26:36,  1.99it/s] @> 1437 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1317 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1278 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.10s.
# @> 1111 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1092 atoms and 1 coordinate set(s) were parsed in 0.04s.
#   1%|          | 16/3184 [00:08<13:45,  3.84it/s]@> 1315 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1577 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1416 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1507 atoms and 1 coordinate set(s) were parsed in 0.07s.
#   1%|          | 20/3184 [00:08<09:42,  5.44it/s]@> 1129 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1368 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1767 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1709 atoms and 1 coordinate set(s) were parsed in 0.06s.
#   1%|          | 25/3184 [00:08<06:36,  7.97it/s]@> 1422 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1480 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1305 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> 1513 atoms and 1 coordinate set(s) were parsed in 0.06s.
#   1%|          | 29/3184 [00:08<05:06, 10.28it/s]@> 1380 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1859 atoms and 1 coordinate set(s) were parsed in 0.07s.
# @> 1329 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1339 atoms and 1 coordinate set(s) were parsed in 0.08s.
#   1%|          | 33/3184 [00:08<04:07, 12.74it/s]@> 1473 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1721 atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 1372 atoms and 1 coordinate set(s) were parsed in 0.09s.
# @> 1170 atoms and 1 coordinate set(s) were parsed in 0.09s.
#   1%|          | 37/3184 [00:09<03:23, 15.49it/s]@> 833 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1074 atoms and 1 coordinate set(s) were parsed in 0.11s.
# @> 1136 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 1734 atoms and 1 coordinate set(s) were parsed in 0.06s.
#   1%|▏         | 42/3184 [00:09<02:35, 20.23it/s]@> 1513 atoms and 1 coordinate set(s) were parsed in 0.05s.
# @> 
atoms and 1 coordinate set(s) were parsed in 0.06s.
# @> 942 atoms and 1 coordinate set(s) were parsed in 0.04s.
# 100%|██████████| 3184/3184 [01:43<00:00, 30.69it/s]
# Computed invariants in 110.14 seconds
# 100%|██████████| 3184/3184 [00:02<00:00, 1430.26it/s]

# %% [markdown]
# Store matrix with annotations

# %%
proteins = [protein.replace('.pdb', '') for protein in shapemer_class.protein_keys]
shapemers = shapemer_class.shapemer_keys
matrix = pd.DataFrame(normalized_matrix, index = proteins, columns = shapemers)
matrix.to_pickle(f'{STRUCTURE_CLUSTERING}/default_core.pkl')

# %% [markdown]
# Dimensionality reduction

# %%
# UMAP
umap_space = UMAP.UMAP(
    metric = "cosine", 
    n_components = 3613
    ).fit_transform(normalized_matrix)

# PCA
pca = PCA()
pca_space = pca.fit_transform(normalized_matrix)

# PCA scree plot
PC_values = np.arange(pca.n_components_) + 1
PC_cumulative = pca.explained_variance_ratio_.cumsum()
# Out:
# /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:1592: RuntimeWarning: k >= N for N * N square matrix. Attempting to use scipy.linalg.eigh instead.
#   warnings.warn("k >= N for N * N square matrix. "
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 # UMAP
#       2 umap_space = UMAP.UMAP(
#       3     metric = "cosine",
#       4     n_components = 3613
# ----> 5     ).fit_transform(normalized_matrix)
#       7 # PCA
#       8 pca = PCA()
#
# File /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/umap_.py:2772, in UMAP.fit_transform(self, X, y)
#    2742 def fit_transform(self, X, y=None):
#    2743     """Fit X into an embedded space and return that transformed
#    2744     output.
#    2745
#    (...)
#    2770         Local radii of data points in the embedding (log-transformed).
#    2771     """
# -> 2772     self.fit(X, y)
#    2773     if self.transform_mode == "embedding":
#    2774         if self.output_dens:
#
# File /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/umap_.py:2684, in UMAP.fit(self, X, y)
#    2681     print(ts(), "Construct embedding")
#    2683 if self.transform_mode == "embedding":
# -> 2684     self.embedding_, aux_data = self._fit_embed_data(
#    2685         self._raw_data[index],
#    2686         self.n_epochs,
#    2687         init,
#    2688         random_state,  # JH why raw data?
#    2689     )
#    2690     # Assign any points that are fully disconnected from our manifold(s) to have embedding
#    2691     # coordinates of np.nan.  These will be filtered by our plotting functions automatically.
#    2692     # They also prevent users from being deceived a distance query to one of these points.
#    2693     # Might be worth moving this into simplicial_set_embedding or _fit_embed_data
#    2694     disconnected_vertices = np.array(self.graph_.sum(axis=1)).flatten() == 0
#
# File /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/umap_.py:2717, in UMAP._fit_embed_data(self, X, n_epochs, init, random_state)
#    2713 def _fit_embed_data(self, X, n_epochs, init, random_state):
#    2714     """A method wrapper for simplicial_set_embedding that can be
#    2715     replaced by subclasses.
#    2716     """
# -> 2717     return simplicial_set_embedding(
#    2718         X,
#    2719         self.graph_,
#    2720         self.n_components,
#    2721         self._initial_alpha,
#    2722         self._a,
#    2723         self._b,
#    2724         self.repulsion_strength,
#    2725         self.negative_sample_rate,
#    2726         n_epochs,
#    2727         init,
#    2728         random_state,
#    2729         self._input_distance_func,
#    2730         self._metric_kwds,
#    2731         self.densmap,
#    2732         self._densmap_kwds,
#    2733         self.output_dens,
#    2734         self._output_distance_func,
#    2735         self._output_metric_kwds,
#    2736         self.output_metric in ("euclidean", "l2"),
#    2737         self.random_state is None,
#    2738         self.verbose,
#    2739         tqdm_kwds=self.tqdm_kwds,
#    2740     )
#
# File /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/umap_.py:1078, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1073     embedding = random_state.uniform(
#    1074         low=-10.0, high=10.0, size=(graph.shape[0], n_components)
#    1075     ).astype(np.float32)
#    1076 elif isinstance(init, str) and init == "spectral":
#    1077     # We add a little noise to avoid local minima for optimization to come
# -> 1078     initialisation = spectral_layout(
#    1079         data,
#    1080         graph,
#    1081         n_components,
#    1082         random_state,
#    1083         metric=metric,
#    1084         metric_kwds=metric_kwds,
#    1085     )
#    1086     expansion = 10.0 / np.abs(initialisation).max()
#    1087     embedding = (initialisation * expansion).astype(
#    1088         np.float32
#    1089     ) + random_state.normal(
#    (...)
#    1092         np.float32
#    1093     )
#
# File /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/umap/spectral.py:332, in spectral_layout(data, graph, dim, random_state, metric, metric_kwds)
#     330 try:
#     331     if L.shape[0] < 2000000:
# --> 332         eigenvalues, eigenvectors = scipy.sparse.linalg.eigsh(
#     333             L,
#     334             k,
#     335             which="SM",
#     336             ncv=num_lanczos_vectors,
#     337             tol=1e-4,
#     338             v0=np.ones(L.shape[0]),
#     339             maxiter=graph.shape[0] * 5,
#     340         )
#     341     else:
#     342         eigenvalues, eigenvectors = scipy.sparse.linalg.lobpcg(
#     343             L, random_state.normal(size=(L.shape[0], k)), largest=False, tol=1e-8
#     344         )
#
# File /lustre/BIF/nobackup/sanch046/miniconda3/envs/geometricus/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:1597, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1592 warnings.warn("k >= N for N * N square matrix. "
#    1593               "Attempting to use scipy.linalg.eigh instead.",
#    1594               RuntimeWarning)
#    1596 if issparse(A):
# -> 1597     raise TypeError("Cannot use scipy.linalg.eigh for sparse A with "
#    1598                     "k >= N. Use scipy.linalg.eigh(A.toarray()) or"
#    1599                     " reduce k.")
#    1600 if isinstance(A, LinearOperator):
#    1601     raise TypeError("Cannot use scipy.linalg.eigh for LinearOperator "
#    1602                     "A with k >= N.")
#
# TypeError: Cannot use scipy.linalg.eigh for sparse A with k >= N. Use scipy.linalg.eigh(A.toarray()) or reduce k.

# %% [markdown]
# Add annotations to embeddings and prepare them for plotting

# %%
# Add family
with open(f'{CAZY_DATA}/uniprot_family.pkl', 'rb') as dic:
    dic = pickle.load(dic)

# Add annotations to embeddings

umap = pd.DataFrame(umap_space[:, 0:2], index = proteins)
pca = pd.DataFrame(pca_space[:, 0:2], index = proteins)
families = [dic[protein] for protein in proteins]
umap['Family'] = families
pca['Family'] = families

# Disregard AA0
umap = umap[umap['Family'] != 'AA0']
pca = pca[pca['Family'] != 'AA0']

# One Hot Encode families into colors
dummies = pd.get_dummies(umap['Family'])

# Translate family to color
family_color = {
    'AA9' : '#1f77b4',
    'AA10' : '#ff7f0e',
    'AA11' : '#2ca02c',
    'AA13' : '#d62728',
    'AA14' : '#9467bd',
    'AA15' : '#8c564b',
    'AA16' : '#e377c2',
    'AA17' : '#bcbd22'
}
for column in dummies:
    dummies[column] = dummies[column].replace(1, family_color[column])
    dummies[column] = dummies[column].replace(0, 'grey')

# %% [markdown]
# Plotly

# %%
# Scatter plots
scatter_umap = go.Scatter(
    x = umap[0],
    y = umap[1],
    name = "Default UMAP",
    mode = 'markers',
    visible = True,
    hovertemplate = umap.index.to_list(),
    marker = dict(color = ['grey']*len(dummies))
)

scatter_pca = go.Scatter(
    x = pca[0],
    y = pca[1],
    name = "Default PCA",
    mode = 'markers',
    visible = False,
    hovertemplate = pca.index.to_list(),
    marker=dict(color = ['grey']*len(dummies))
)
x = np.arange(10)
scree_plot = go.Scatter(
    x = PC_values, 
    y = PC_cumulative, 
    visible = False
    )

fig = go.FigureWidget([scatter_umap, scatter_pca, scree_plot])

button_layer_1_height = 1.11
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                
                dict(
                    label = "None",
                    args = [{"marker": {"color":['grey']*len(dummies)}}],
                    method = "restyle"
                ),  
                
                dict(
                    label = "AA9",
                    args = [{"marker": {"color": dummies['AA9']}}],
                    method = "restyle"
                ),    

                dict(
                    label = "AA10",
                    args = [{"marker": {"color": dummies['AA10']}}],
                    method = "restyle"
                ),   
                
                dict(
                    label = "AA11",
                    args = [{"marker": {"color": dummies['AA11']}}],
                    method = "restyle"
                ),   

                dict(
                    label = "AA13",
                    args = [{"marker": {"color": dummies['AA13']}}],
                    method = "restyle"
                ), 
                
                dict(
                    label = "AA14",
                    args = [{"marker": {"color": dummies['AA14']}}],
                    method = "restyle"
                ),   

                dict(
                    label = "AA15",
                    args = [{"marker": {"color": dummies['AA15']}}],
                    method = "restyle"
                ),   

                dict(
                    label = "AA16",
                    args = [{"marker": {"color": dummies['AA16']}}],
                    method = "restyle"
                ),                  
                
                dict(
                    label = "AA17",
                    args = [{"marker": {"color": dummies['AA17']}}],
                    method = "restyle"
                ),   

            ]), 
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.20,
            xanchor="left",
            y=button_layer_1_height,
            yanchor="top"
        ),
        dict(
            buttons=list([
                dict(label="UMAP",
                     method="update",
                     args=[{"visible": [True, False, False]},
                           {"title": "UMAP"}]),
                dict(label="PCA",
                     method="update",
                     args=[{"visible": [False, True, False]},
                           {"title": "PCA"}]),
                dict(label="Scree",
                     method="update",
                     args=[{"visible": [False, False, True]},
                           {"title": "Scree plot"}]               
                ),
            ]),
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0,
            xanchor="left",
            y=button_layer_1_height,
            yanchor="top"
        )
    ]
)

# Update size 
fig.update_layout(
    autosize=False,
    width=600,
    height=600)

# Create our callback function
def selection_fn(trace, points, selector):
    # Give shapemer and protein info to normalized_matrix
    df = pd.DataFrame(
        data = normalized_matrix, 
        columns = shapemer_class.shapemer_keys,
        index = [key.split('.')[0] for key in shapemer_class.protein_keys]
        )
    
    # Calculate most frequent shapemer/protein
    point_indeces = points.point_inds
    if point_indeces:
        print(point_indeces)
        points = df.iloc[point_indeces].to_numpy()
        point_names = set(df.iloc[point_indeces].index)
        index = np.unravel_index(np.argmax(points, axis=None), points.shape)
        most_frequent_shapemer = df.columns[index[1]]
        print(most_frequent_shapemer)

        # Map shapemer to residues
        selectedname_residue = dict()
        name_residue = dict(shapemer_class.map_shapemer_to_residues(most_frequent_shapemer))
        for name in point_names:
            if name + '.pdb' in name_residue:
                selectedname_residue[name] = name_residue[name + '.pdb']
        print(selectedname_residue)

fig.data[0].on_selection(selection_fn)
fig.data[1].on_selection(selection_fn)

fig
# Out:
# FigureWidget({
#     'data': [{'hovertemplate': [A0A1B3XTW0, A0A6S6VTC2, A0A1H0DH62, ...,
#                                 A0A084VRN9, A0A6G7P3W3, K1PFV1],
#               'marker': {'color': [grey, grey, grey, ..., grey, grey, grey]},
#               'mode': 'markers',
#               'name': 'Default UMAP',
#               'type': 'scatter',
#               'uid': '5db262e2-e8f3-4d48-8ead-c9e16fb84829',
#               'visible': True,
#               'x': array([-0.5931787,  9.492236 , -3.1971142, ...,  8.164263 , 13.407613 ,
#                           10.294798 ], dtype=float32),
#               'y': array([ 5.3337007, -1.3140765,  1.1771177, ...,  6.332697 ,  7.002878 ,
#                            3.9253902], dtype=float32)},
#              {'hovertemplate': [A0A1B3XTW0, A0A6S6VTC2, A0A1H0DH62, ...,
#                                 A0A084VRN9, A0A6G7P3W3, K1PFV1],
#               'marker': {'color': [grey, grey, grey, ..., grey, grey, grey]},
#               'mode': 'markers',
#               'name': 'Default PCA',
#               'type': 'scatter',
#               'uid': '76c3575a-7649-40d3-ab1f-9a500b37744b',
#               'visible': False,
#               'x': array([-0.01971415, -0.0451335 , -0.003106  , ..., -0.01117462,  0.0707514 ,
#                            0.03311648]),
#               'y': array([ 0.00315763, -0.0075435 , -0.03112857, ...,  0.0004585 , -0.02481595,
#                            0.06144361])},
#              {'type': 'scatter',
#               'uid': 'e6ce2291-73e0-4afe-b20f-f0bff80d7b16',
#               'visible': False,
#               'x': array([  1,   2,   3, ..., 358, 359, 360]),
#               'y': array([0.24646233, 0.39797439, 0.50519509, ..., 1.        , 1.        ,
#                           1.        ])}],
#     'layout': {'autosize': False,
#                'height': 600,
#                'template': '...',
#                'updatemenus': [{'buttons': [{'args': [{'marker': {'color': [grey,
#                                                                             grey,
#                                                                             grey,
#                                                                             ...,
#                                                                             grey,
#                                                                             grey,
#                                                                             grey]}}],
#                                              'label': 'None',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0       grey
#    A0A6S6VTC2    #1f77b4
#    A0A1H0DH62       grey
#    G8YZS8        #1f77b4
#    A0A7S8HTC2    #1f77b4
#                   ...
#    A0A7R7XBI8       grey
#    A0A127Q5Y5       grey
#    A0A084VRN9       grey
#    A0A6G7P3W3       grey
#    K1PFV1           grey
#    Name: AA9, Length: 3614, dtype: object}}],
#                                              'label': 'AA9',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0    #ff7f0e
#    A0A6S6VTC2       grey
#    A0A1H0DH62    #ff7f0e
#    G8YZS8           grey
#    A0A7S8HTC2       grey
#                   ...
#    A0A7R7XBI8       grey
#    A0A127Q5Y5    #ff7f0e
#    A0A084VRN9       grey
#    A0A6G7P3W3    #ff7f0e
#    K1PFV1           grey
#    Name: AA10, Length: 3614, dtype: object}}],
#                                              'label': 'AA10',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0    grey
#    A0A6S6VTC2    grey
#    A0A1H0DH62    grey
#    G8YZS8        grey
#    A0A7S8HTC2    grey
#                  ...
#    A0A7R7XBI8    grey
#    A0A127Q5Y5    grey
#    A0A084VRN9    grey
#    A0A6G7P3W3    grey
#    K1PFV1        grey
#    Name: AA11, Length: 3614, dtype: object}}],
#                                              'label': 'AA11',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0    grey
#    A0A6S6VTC2    grey
#    A0A1H0DH62    grey
#    G8YZS8        grey
#    A0A7S8HTC2    grey
#                  ...
#    A0A7R7XBI8    grey
#    A0A127Q5Y5    grey
#    A0A084VRN9    grey
#    A0A6G7P3W3    grey
#    K1PFV1        grey
#    Name: AA13, Length: 3614, dtype: object}}],
#                                              'label': 'AA13',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0    grey
#    A0A6S6VTC2    grey
#    A0A1H0DH62    grey
#    G8YZS8        grey
#    A0A7S8HTC2    grey
#                  ...
#    A0A7R7XBI8    grey
#    A0A127Q5Y5    grey
#    A0A084VRN9    grey
#    A0A6G7P3W3    grey
#    K1PFV1        grey
#    Name: AA14, Length: 3614, dtype: object}}],
#                                              'label': 'AA14',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0       grey
#    A0A6S6VTC2       grey
#    A0A1H0DH62       grey
#    G8YZS8           grey
#    A0A7S8HTC2       grey
#                   ...
#    A0A7R7XBI8       grey
#    A0A127Q5Y5       grey
#    A0A084VRN9    #8c564b
#    A0A6G7P3W3       grey
#    K1PFV1        #8c564b
#    Name: AA15, Length: 3614, dtype: object}}],
#                                              'label': 'AA15',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0       grey
#    A0A6S6VTC2       grey
#    A0A1H0DH62       grey
#    G8YZS8           grey
#    A0A7S8HTC2       grey
#                   ...
#    A0A7R7XBI8    #e377c2
#    A0A127Q5Y5       grey
#    A0A084VRN9       grey
#    A0A6G7P3W3       grey
#    K1PFV1           grey
#    Name: AA16, Length: 3614, dtype: object}}],
#                                              'label': 'AA16',
#                                              'method': 'restyle'},
#                                             {'args': [{'marker': {'color': A0A1B3XTW0    grey
#    A0A6S6VTC2    grey
#    A0A1H0DH62    grey
#    G8YZS8        grey
#    A0A7S8HTC2    grey
#                  ...
#    A0A7R7XBI8    grey
#    A0A127Q5Y5    grey
#    A0A084VRN9    grey
#    A0A6G7P3W3    grey
#    K1PFV1        grey
#    Name: AA17, Length: 3614, dtype: object}}],
#                                              'label': 'AA17',
#                                              'method': 'restyle'}],
#                                 'direction': 'down',
#                                 'pad': {'r': 10, 't': 10},
#                                 'showactive': True,
#                                 'x': 0.2,
#                                 'xanchor': 'left',
#                                 'y': 1.11,
#                                 'yanchor': 'top'},
#                                {'buttons': [{'args': [{'visible': [True, False, False]}, {'title': 'UMAP'}],
#                                              'label': 'UMAP',
#                                              'method': 'update'},
#                                             {'args': [{'visible': [False, True, False]}, {'title': 'PCA'}],
#                                              'label': 'PCA',
#                                              'method': 'update'},
#                                             {'args': [{'visible': [False, False, True]}, {'title': 'Scree plot'}],
#                                              'label': 'Scree',
#                                              'method': 'update'}],
#                                 'direction': 'down',
#                                 'pad': {'r': 10, 't': 10},
#                                 'showactive': True,
#                                 'x': 0,
#                                 'xanchor': 'left',
#                                 'y': 1.11,
#                                 'yanchor': 'top'}],
#                'width': 600}
# })
